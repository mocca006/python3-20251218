# %% [markdown]
# # 乳癌診斷預測

# %% [markdown]
# ## 載入套件

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 載入資料

# %%
X, y = datasets.load_breast_cancer(return_X_y=True)

# %% [markdown]
# ## 資料分割

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %% [markdown]
# ## 模型訓練

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

model = SVC()
model.fit(X_train_std, y_train)
# Out:
# SVC()

# %% [markdown]
# ## 模型評分

# %%
model.score(X_test_std, y_test)
# Out:
# 0.9824561403508771

# %% [markdown]
# ## TensorFlow

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(units=2, input_shape=[X.shape[1]], activation='sigmoid')  
    ]
)

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

# %%
history = model.fit(X_train_std, y_train, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt

plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.plot(history.history['loss'])

# %%
model.evaluate(X_test_std, y_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1824 - accuracy: 0.9561
# [0.18241244554519653, 0.9561403393745422]
