# %%
# 查看目前目錄下的次目錄及檔案
# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jul 16 13:20 sample_data

# %%
# !ls -l sample_data/
# Out:
# total 55504
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 Jul 16 13:20 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 Jul 16 13:20 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 Jul 16 13:20 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Jul 16 13:20 mnist_train_small.csv
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md

# %%
# 查看目前路徑
# !pwd
# Out:
# /content

# %%
# 建立 images 目錄
# !mkdir images

# %%
# 更改目前路徑至 images
# %cd images
# Out:
# /content/images

# %%
# 更改目前路徑至上一層
# %cd ..
# Out:
# /content

# %%
# 查看 sample_data 次目錄
# !ls -l sample_data
# Out:
# total 55508
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 May 29 18:19 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 May 29 18:19 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 May 29 18:19 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 May 29 18:19 mnist_train_small.csv
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md

# %%
# !rm 0*.py
# Out:
# rm: cannot remove '0*.py': No such file or directory

# %%
# 檔案上傳，可一次上傳多個檔案
from google.colab import files

uploaded = files.upload()

# 顯示上傳檔案名稱及大小
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-2036fe57-9759-46a1-b728-18c935e5f3e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2036fe57-9759-46a1-b728-18c935e5f3e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0.py to 0.py
# User uploaded file "0.py" with length 3627 bytes

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# arviz                         0.11.2
# astor                         0.8.1
# astropy                       4.2.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.3.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.2
# ...

# %%
# 執行 Python 程式檔
# !python 0.py
# Out:
# 2021-07-25 03:30:17.553701: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# 2021-07-25 03:30:19.945042: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-25 03:30:20.004185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-25 03:30:20.004834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bbd32b88-b11b-4701-a8a4-a0b700ff6dc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bbd32b88-b11b-4701-a8a4-a0b700ff6dc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.zip to data.zip

# %%
# !ls *.* -l
# Out:
# -rw-r--r-- 1 root root    3627 Jul 25 03:29 0.py
# -rw-r--r-- 1 root root 1006472 Jul 25 03:34 data.zip
# -rw-r--r-- 1 root root    1218 Jul 25 03:30 model.config
# -rw-r--r-- 1 root root 2444418 Jul 25 03:30 model.weight.data-00000-of-00001
# -rw-r--r-- 1 root root    1215 Jul 25 03:30 model.weight.index

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a75c6c37-9ea5-4964-acf2-de090ed12135" name="files[]" multiple disabled />
#      <output id="result-a75c6c37-9ea5-4964-acf2-de090ed12135">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving code02.zip to code02.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ed2fd71b4a2f> in <module>()
# ----> 1 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      70     result = _output.eval_js(
#      71         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 72             output_id=output_id))
#      73     if result['action'] != 'append':
# ...

# %%
import pandas as pd
df = pd.read_csv('president_heights.csv')
print(df.head(10))
# Out:
#    order                    name  height(cm)
# 0      1       George Washington         189
# 1      2              John Adams         170
# 2      3        Thomas Jefferson         189
# 3      4           James Madison         163
# 4      5            James Monroe         183
# 5      6       John Quincy Adams         171
# 6      7          Andrew Jackson         185
# 7      8        Martin Van Buren         168
# 8      9  William Henry Harrison         173
# 9     10              John Tyler         183

# %%
# 產生檔案
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

# %%
# %ls sample_data/
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# 下載檔案
files.download('./sample_data/mnist_test.csv')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8eb5aef1-10b9-4e19-90a6-c259d7cd352f" name="files[]" multiple disabled />
#      <output id="result-8eb5aef1-10b9-4e19-90a6-c259d7cd352f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0.zip to 0.zip

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/train/
#    creating: data/train/cats/
#   inflating: data/train/cats/cat.0.jpg
#   inflating: data/train/cats/cat.1.jpg
#   inflating: data/train/cats/cat.10.jpg
#   inflating: data/train/cats/cat.11.jpg
#   inflating: data/train/cats/cat.12.jpg
#   inflating: data/train/cats/cat.13.jpg
#   inflating: data/train/cats/cat.14.jpg
#   inflating: data/train/cats/cat.15.jpg
#   inflating: data/train/cats/cat.16.jpg
#   inflating: data/train/cats/cat.17.jpg
#   inflating: data/train/cats/cat.18.jpg
#   inflating: data/train/cats/cat.19.jpg
#   inflating: data/train/cats/cat.2.jpg
#   inflating: data/train/cats/cat.20.jpg
#   inflating: data/train/cats/cat.21.jpg
#   inflating: data/train/cats/cat.22.jpg
#   inflating: data/train/cats/cat.23.jpg
#   inflating: data/train/cats/cat.24.jpg
#   inflating: data/train/cats/cat.3.jpg
#   inflating: data/train/cats/cat.4.jpg
#   inflating: data/train/cats/cat.5.jpg
# ...

# %%
# 顯示圖檔
from IPython.display import Image

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
Image('data/train/dogs/dog.9.jpg', width=300)

# %%
for i in range(0,3):
  display(Image(filename='data/train/dogs/dog.'+str(i)+'.jpg', width=300, height=None))

# %%
# !ls -l
# Out:
# total 7556
# -rw-r--r-- 1 root root    4441 Jun  7 03:20 0.png
# -rw-r--r-- 1 root root    3847 Jun  6 23:13 0.py
# -rw-r--r-- 1 root root    2075 Jun  7 03:29 0.zip
# -rw-r--r-- 1 root root    1794 Jun  7 03:20 1.png
# -rw-r--r-- 1 root root    2881 Jun  7 03:20 2.png
# -rw-r--r-- 1 root root    3781 Jun  7 03:20 3.png
# -rw-r--r-- 1 root root 6860800 Jun  7 03:29 code02.zip
# -rw-r--r-- 1 root root      12 Jun  7 03:26 example.txt
# drwxr-xr-x 2 root root    4096 Jun  7 03:17 images
# -rw-r--r-- 1 root root    1069 Jun  7 03:22 model.config
# -rw-r--r-- 1 root root  827392 Jun  7 03:22 model.weight
# -rw-r--r-- 1 root root     988 Jun  7 03:25 president_heights.csv
# drwxr-xr-x 1 root root    4096 May 29 18:19 sample_data

# %%
# 連結 google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 查看 google drive
# !ls /content/drive -l
# Out:
# total 4
# drwx------ 18 root root 4096 Jul 25 03:42 MyDrive

# %%
# 更改目前路徑至 google drive 的根目錄
# %cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
ls -l
# Out:
# total 2580
# drwx------ 2 root root    4096 Nov 17  2020  0/
# -rw------- 1 root root   26380 Nov 22  2020  02_個股日成交資訊.ipynb
# -rw------- 1 root root    9143 Apr 12 12:27  0412.ipynb
# -rw------- 1 root root     657 Nov  8  2020  1.py
# -rw------- 1 root root   29080 Oct 18  2020  20201018_class1.ipynb
# -rw------- 1 root root   36004 Oct 25  2020  20201025_class2.ipynb
# -rw------- 1 root root   35024 Nov  1  2020  20201101_class4.ipynb
# -rw------- 1 root root   24501 Nov  1  2020  20201101_class5.ipynb
# -rw------- 1 root root   47118 Nov  8  2020  20201108_class06.ipynb
# -rw------- 1 root root    3844 Nov  8  2020  20201108_class07.ipynb
# -rw------- 1 root root   18041 Nov 14  2020  20201114_class1.ipynb
# -rw------- 1 root root   19475 Nov 21  2020  20201121_class3.ipynb
# -rw------- 1 root root    6289 Nov 22  2020  20201122_class7.ipynb
# -rw------- 1 root root   48049 Nov 22  2020  20201122_class8.ipynb
# ...

# %%
# %cd "三階/test"
# Out:
# /content/drive/My Drive/三階/test

# %%
ls
# Out:
# 03_1_張量運算.ipynb  03_2_自動微分.ipynb  Colab_Link_Upload.ipynb  data.zip

# %%
# !cp data.zip /content/data2.zip

# %%
ls /content
# Out:
#  0.py         data2.zip   images/                            model.weight.index
#  checkpoint   data.zip    model.config                       sample_data/
#  data/        drive/      model.weight.data-00000-of-00001  'view?usp=sharing'

# %%
# https://www.opencli.com/linux/linux-zip-unzip
# !unzip ./data.zip -d /content
# Out:
# Archive:  ./data.zip
# replace /content/data/train/cats/cat.0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/data/train/cats/cat.0.jpg
#   inflating: /content/data/train/cats/cat.1.jpg
#   inflating: /content/data/train/cats/cat.10.jpg
#   inflating: /content/data/train/cats/cat.11.jpg
#   inflating: /content/data/train/cats/cat.12.jpg
#   inflating: /content/data/train/cats/cat.13.jpg
#   inflating: /content/data/train/cats/cat.14.jpg
#   inflating: /content/data/train/cats/cat.15.jpg
#   inflating: /content/data/train/cats/cat.16.jpg
#   inflating: /content/data/train/cats/cat.17.jpg
#   inflating: /content/data/train/cats/cat.18.jpg
#   inflating: /content/data/train/cats/cat.19.jpg
#   inflating: /content/data/train/cats/cat.2.jpg
#   inflating: /content/data/train/cats/cat.20.jpg
#   inflating: /content/data/train/cats/cat.21.jpg
#   inflating: /content/data/train/cats/cat.22.jpg
#   inflating: /content/data/train/cats/cat.23.jpg
# ...

# %%
# %cd /content
# !gdown https://drive.google.com/uc?id=1stxMMDdlvzI2jIkXoX-LrYqp-S5_OUVq
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1stxMMDdlvzI2jIkXoX-LrYqp-S5_OUVq
# To: /content/data.zip
# 100% 1.01M/1.01M [00:00<00:00, 66.0MB/s]

# %%
cd /content
# Out:
# /content

# %%
ls
# Out:
#  0.py         data2.zip   images/                            model.weight.index
#  checkpoint   data.zip    model.config                       sample_data/
#  data/        drive/      model.weight.data-00000-of-00001  'view?usp=sharing'

# %%
# 安裝 opencv 套件
# !pip install opencv-python

# %%
# 查詢安裝的套件
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------
# absl-py                  0.9.0
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   4.1.0
# asgiref                  3.2.7
# astor                    0.8.1
# astropy                  4.0.1.post1
# astunparse               1.6.3
# atari-py                 0.2.6
# atomicwrites             1.4.0
# attrs                    19.3.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.8.0
# backcall                 0.1.0
# beautifulsoup4           4.6.3
# bleach                   3.1.5
# blis                     0.4.1
# bokeh                    1.4.0
# boto                     2.49.0
# boto3                    1.13.19
# botocore                 1.16.19
# Bottleneck               1.3.2
# branca                   0.4.1
# bs4                      0.0.1
# CacheControl             0.12.6
# cachetools               3.1.1
# ...

# %%
# 顯示虛擬機配備
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15065454608312154953, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6973911419267835591
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17288710215110238554
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8302654442123883112
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]
